# %%
import nltk

# %%
#loading custom text 
di = open("dec_independence.txt")

# %%
diText = di.read()

# %%
#tokenize
diTextTokens = nltk.word_tokenize(diText)

# %%
#Frequency Distribution
nltk.FreqDist(diTextTokens)
# Out:
# FreqDist({"'s": 2,
#           ',': 104,
#           '--': 1,
#           '.': 36,
#           ':': 10,
#           ';': 10,
#           'A': 1,
#           'America': 1,
#           'And': 1,
#           'Britain': 2,
#           'British': 2,
#           'But': 1,
#           'Congress': 1,
#           'Creator': 1,
#           'Crown': 1,
#           'Divine': 1,
#           'English': 1,
#           'For': 9,
#           'General': 1,
#           'God': 1,
#           'Great': 2,
#           'He': 18,
#           'In': 2,
#           'Indian': 1,
#           'Jefferson': 1,
#           'Judge': 1,
#           'King': 1,
#           'Nor': 1,
#           'Providence': 1,
#           'Prudence': 1,
#           'States': 1,
#           'Such': 1,
#           'Supreme': 1,
#           'That': 2,
#           'The': 1,
#           'To': 1,
#           'United': 1,
#           'We': 6,
#           'When': 1,
#           'a': 15,
#           'abdicated': 1,
#           'abolish': 1,
# ...

# %%
type(diTextTokens)
# Out:
# list
